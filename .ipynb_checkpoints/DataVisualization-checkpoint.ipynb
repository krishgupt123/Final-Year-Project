# %% [markdown]
# ## DATA VISUALIZATION AND ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('CYBER.csv')

# %%
df.head()
# Out:
#    'Flow Duration'  'Tot Fwd Pkts'  'Tot Bwd Pkts'  'TotLen Fwd Pkts'  \
# 0             1518               2               5                110
# 1             5894               4               8                168
# 2              272               1               1                  0
# 3             2611               4               8                322
# 4              294               1               1                  0
#
#    'TotLen Bwd Pkts'  'Fwd Pkt Len Max'  'Fwd Pkt Len Min'  \
# 0                377                110                  0
# 1               4498                168                  0
# 2                  0                  0                  0
# 3               4434                322                  0
# 4                  0                  0                  0
#
#    'Fwd Pkt Len Mean'  'Fwd Pkt Len Std'  'Bwd Pkt Len Max'  ...  \
# 0                55.0            77.7817                377  ...
# 1                42.0            84.0000               1460  ...
# 2                 0.0             0.0000                  0  ...
# 3                80.5           161.0000               1460  ...
# 4                 0.0             0.0000                  0  ...
#
#    'Fwd Act Data Pkts'  'Active Mean'  'Active Std'  'Active Max'  \
# 0                    1              0             0             0
# 1                    1              0             0             0
# 2                    0              0             0             0
# 3                    1              0             0             0
# 4                    0              0             0             0
#
#    'Active Min'  'Idle Mean'  'Idle Std'  'Idle Max'  'Idle Min'        Label
# 0             0            0           0           0           0  Brute_Force
# 1             0            0           0           0           0  Brute_Force
# 2             0            0           0           0           0  Brute_Force
# 3             0            0           0           0           0  Brute_Force
# 4             0            0           0           0           0  Brute_Force
#
# [5 rows x 67 columns]

# %%
df = df.dropna()

# %%
df=df.drop_duplicates()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Label']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Label',data=df)
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
# Plot a Histogram
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.hist(df["'Flow Duration'"],color='red')
plt.subplot(1,2,2)
plt.hist(df["'Active Std'"],color='blue')
# Out:
# (array([9.0985e+04, 5.7400e+02, 1.7400e+02, 1.5900e+02, 5.7000e+01,
#         3.4000e+01, 3.5000e+01, 6.0000e+00, 7.0000e+00, 4.0000e+00]),
#  array([       0. ,  7025067.2, 14050134.4, 21075201.6, 28100268.8,
#         35125336. , 42150403.2, 49175470.4, 56200537.6, 63225604.8,
#         70250672. ]),
#  <BarContainer object of 10 artists>)

# %%
df.columns
# Out:
# Index([''Flow Duration'', ''Tot Fwd Pkts'', ''Tot Bwd Pkts'',
#        ''TotLen Fwd Pkts'', ''TotLen Bwd Pkts'', ''Fwd Pkt Len Max'',
#        ''Fwd Pkt Len Min'', ''Fwd Pkt Len Mean'', ''Fwd Pkt Len Std'',
#        ''Bwd Pkt Len Max'', ''Bwd Pkt Len Min'', ''Bwd Pkt Len Mean'',
#        ''Bwd Pkt Len Std'', ''Flow Byts/s'', ''Flow Pkts/s'',
#        ''Flow IAT Mean'', ''Flow IAT Std'', ''Flow IAT Max'', ''Flow IAT Min'',
#        ''Fwd IAT Tot'', ''Fwd IAT Mean'', ''Fwd IAT Std'', ''Fwd IAT Max'',
#        ''Fwd IAT Min'', ''Bwd IAT Tot'', ''Bwd IAT Mean'', ''Bwd IAT Std'',
#        ''Bwd IAT Max'', ''Bwd IAT Min'', ''Bwd PSH Flags'', ''Bwd URG Flags'',
#        ''Fwd Header Len'', ''Bwd Header Len'', ''Fwd Pkts/s'', ''Bwd Pkts/s'',
#        ''Pkt Len Min'', ''Pkt Len Max'', ''Pkt Len Mean'', ''Pkt Len Std'',
#        ''Pkt Len Var'', ''FIN Flag Cnt'', ''SYN Flag Cnt'', ''RST Flag Cnt'',
#        ''PSH Flag Cnt'', ''ACK Flag Cnt'', ''URG Flag Cnt'',
#        ''CWE Flag Count'', ''ECE Flag Cnt'', ''Down/Up Ratio'',
#        ''Pkt Size Avg'', ''Fwd Seg Size Avg'', ''Bwd Seg Size Avg'',
#        ''Subflow Fwd Pkts'', ''Subflow Fwd Byts'', ''Subflow Bwd Pkts'',
#        ''Subflow Bwd Byts'', ''Init Bwd Win Byts'', ''Fwd Act Data Pkts'',
#        ''Active Mean'', ''Active Std'', ''Active Max'', ''Active Min'',
#        ''Idle Mean'', ''Idle Std'', ''Idle Max'', ''Idle Min'', 'Label'],
#       dtype='object')

# %%
df.hist(figsize=(15,55), color='green')
plt.show()

# %%
df["'Pkt Len Mean'"].hist(figsize=(10,5),color='yellow',bins=25)
# Out:
# <Axes: >

# %%
# Check the outliers our datasets.
plt.boxplot(df["'Pkt Size Avg'"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0176648d0>,
#   <matplotlib.lines.Line2D at 0x1d017665390>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d0176651d0>,
#   <matplotlib.lines.Line2D at 0x1d019cc4710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d019676e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d017666c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d019cd0050>],
#  'means': []}

# %%
# Plot a density plot
df["'Pkt Len Mean'"].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Plot a distance plot
sns.displot(df["'Bwd Pkt Len Mean'"], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
# Plot a distance plot.
sns.displot(df["'Pkt Len Mean'"], color='coral') # residplot, scatterplot

# %%
# Plotting a heatmap for determining the correlation among the columns.
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Plot a Piechart 
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = )
    ax.set_title(variable + ' \n', fontsize = 6)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Label')
# Out:
# 0    67.39
# 3    28.48
# 4     3.58
# 1     0.48
# 2     0.05
# 5     0.03
# Name: Label, dtype: float64
